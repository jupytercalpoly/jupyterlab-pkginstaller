# %%
import error_1
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-57-866922aaa0de> in <module>
# ----> 1 import error_1
#
# ModuleNotFoundError: No module named 'error_1'

# %%
import error_2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-2cda3f86d6ee> in <module>
# ----> 1 import error_2
#
# ModuleNotFoundError: No module named 'error_2'

# %%
import error_3
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-f1b5177a7e40> in <module>
# ----> 1 import error_3
#
# ModuleNotFoundError: No module named 'error_3'

# %%
import error_6
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-60-a1c72ee0f298> in <module>
# ----> 1 import error_6
#
# ModuleNotFoundError: No module named 'error_6'

# %%
import error_7
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-61-4e2446621e51> in <module>
# ----> 1 import error_7
#
# ModuleNotFoundError: No module named 'error_7'

# %%
print("HIYA")
import asdasd
# Out:
# HIYA
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-25-7568c669fe09> in <module>
#       1 print("HIYA")
# ----> 2 import asdasd
#
# ModuleNotFoundError: No module named 'asdasd'

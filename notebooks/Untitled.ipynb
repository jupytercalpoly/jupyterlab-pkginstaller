# %%
import asdasd, fghfgh, asdasd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-b585baa361c6> in <module>
# ----> 1 import asdasd, fghfgh, asdasd
#
# ModuleNotFoundError: No module named 'asdasd'

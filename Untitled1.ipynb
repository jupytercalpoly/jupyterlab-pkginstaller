# %%
import sad
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-22-64c582ab7431> in <module>
# ----> 1 import sad
#
# ModuleNotFoundError: No module named 'sad'

# %%
import asdasd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-23-7ad967ca1c65> in <module>
# ----> 1 import asdasd
#
# ModuleNotFoundError: No module named 'asdasd'
